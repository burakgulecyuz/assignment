# %%
import pandas as pd

# Read the data from the CSV files
file1 = "Industry _including_construction_value_added_(current US$).csv"
file2 = "Industry_including_construction_value_added_ _of_GDP.csv"
file3 = "Labor_force_total.csv"
file4 = "Unemployment_total_ _of_total_labor_force.csv"

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0               68 non-null     object
#  1   2000        68 non-null     object
#  2   2001        68 non-null     object
#  3   2002        68 non-null     object
#  4   Unnamed: 4  0 non-null      float64
#  5   2003        68 non-null     object
#  6   2004        68 non-null     object
#  7   2005        68 non-null     object
#  8   2006        68 non-null     object
#  9   2007        68 non-null     object
#  10  2008        68 non-null     object
#  11  2009        68 non-null     object
#  12  2010        68 non-null     object
#  13  2011        68 non-null     object
#  14  2012        68 non-null     object
#  15  2013        68 non-null     object
#  16  2014        68 non-null     object
#  17  2015        68 non-null     object
#  18  2016        68 non-null     object
# ...

# %%
#now drop unnamed: 4 column
df1 = df1.drop(columns=['Unnamed: 4'])

# %%
df1.head()
# Out:
#                          2000               2001               2002  \
# 0  Ireland   31,566,722,637.1   37,268,758,566.1   45,143,959,977.4
# 1  Germany  539,832,139,038.4  526,709,873,232.7  548,277,686,693.3
# 2  Belgium   59,065,114,871.1   57,558,079,403.3   61,462,575,829.0
# 3  Denmark   38,827,989,880.1   37,721,939,131.1   40,471,111,505.2
# 4   Greece   24,457,701,784.8   26,352,365,530.7   30,045,306,326.2
#
#                 2003               2004               2005               2006  \
# 0   53,121,134,676.0   59,800,704,626.7   63,635,542,139.5   69,840,796,138.2
# 1  655,099,098,353.3  743,125,902,473.0  750,242,418,303.5  807,803,314,704.7
# 2   73,879,931,157.1   84,771,694,096.0   87,070,394,710.7   90,388,424,787.9
# 3   48,336,610,349.6   55,627,917,744.7   58,816,297,753.8   64,553,196,004.6
# 4   41,521,328,053.9   49,021,674,077.8   44,132,955,361.2   54,674,449,338.8
#
#                 2007                 2008  ...               2012  \
# ...

# %%
#now change all the cloumns values comas to dots
df1 = df1.applymap(lambda x: x.replace(",", ""))
"""
for col in df1.columns:
    df1[col] = df1[col].str.replace(",", "")
""" ## we could use this method too
# Out:
# '\nfor col in df1.columns:\n    df1[col] = df1[col].str.replace(",", "")\n'

# %%
for column in df1.columns:
    df1.iloc[:,1:] = df1.iloc[:,1:].apply(lambda x: float(x) if isinstance(x, str) else x) #convert all the values to float

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0                68 non-null     object
#  1   2000         68 non-null     object
#  2   2001         68 non-null     object
#  3   2002         68 non-null     float64
#  4   2003         68 non-null     float64
#  5   2004         68 non-null     float64
#  6   2005         68 non-null     float64
#  7   2006         68 non-null     float64
#  8   2007         68 non-null     float64
#  9   2008         68 non-null     float64
#  10  2009         68 non-null     float64
#  11  Unnamed: 11  0 non-null      float64
#  12  2010         68 non-null     float64
#  13  2011         68 non-null     float64
#  14  2012         68 non-null     float64
#  15  2013         68 non-null     float64
#  16  2014         68 non-null     float64
#  17  2015         68 non-null     float64
# ...

# %%
#now drop unnamed: 11 column
df2 = df2.drop(columns=['Unnamed: 11'])

# %%
df2.head()
# Out:
#             2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  2012  \
# 0  Ireland  31.5  34.1  35.1  32.3  30.8  30.0  30.1  28.5  25.9  ...  23.9
# 1  Germany  27.7  27.1  26.4  26.2  26.4  26.4  27.0  27.2  26.8  ...  27.3
# 2  Belgium  24.9  24.3  23.8  23.2  23.0  22.6  22.1  22.3  21.6  ...  20.1
# 3  Denmark  23.7  22.9  22.7  22.2  22.1  22.2  22.8  22.2  22.6  ...  20.4
# 4   Greece  18.7  19.3  19.4  20.5  20.3  17.8  20.0  18.0  15.7  ...  14.8
#
#    2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  23.9  24.3  38.2  36.9  35.9  36.7  35.4  37.5  37.8
# 1  26.8  27.0  27.1  27.6  27.5  27.3  27.0  26.6  26.7
# 2  19.9  19.7  19.7  19.3  19.2  18.9  19.3  19.5  19.6
# 3  20.1  19.8  20.0  20.7  20.7  20.8  20.7  20.0  19.3
# 4  15.1  14.1  14.5  14.5  13.7  13.6  13.4  15.0  15.3
#
# [5 rows x 23 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0               68 non-null     object
#  1   2000        68 non-null     object
#  2   2001        68 non-null     object
#  3   2002        68 non-null     object
#  4   2003        68 non-null     object
#  5   Unnamed: 5  0 non-null      float64
#  6   2004        68 non-null     object
#  7   2005        68 non-null     object
#  8   2006        68 non-null     object
#  9   2007        68 non-null     object
#  10  2008        68 non-null     object
#  11  2009        68 non-null     object
#  12  2010        68 non-null     object
#  13  2011        68 non-null     object
#  14  2012        68 non-null     object
#  15  2013        68 non-null     object
#  16  2014        68 non-null     object
#  17  2015        68 non-null     object
#  18  2016        68 non-null     object
# ...

# %%
#now drop unnamed: 5 column
df3 = df3.drop(columns=['Unnamed: 5'])

# %%
#now change all the cloumns values comas to dots
df3 = df3.applymap(lambda x: x.replace(",", ""))

# %%
df3.head()
# Out:
#                   2000        2001        2002        2003        2004  \
# 0  Ireland   1862430.0   1898123.0   1941828.0   1984446.0   2033886.0
# 1  Germany  39865801.0  40029198.0  40056637.0  40236914.0  40039826.0
# 2  Belgium   4416525.0   4315763.0   4365043.0   4402418.0   4485839.0
# 3  Denmark   2853060.0   2841507.0   2868928.0   2868194.0   2895623.0
# 4   Greece   4860889.0   4819343.0   4881094.0   4935423.0   5019191.0
#
#          2005        2006        2007        2008  ...        2012  \
# 0   2151141.0   2241382.0   2336096.0   2355177.0  ...   2225018.0
# 1  41239999.0  41693116.0  41861246.0  41917490.0  ...  41853628.0
# 2   4626679.0   4646803.0   4728844.0   4777353.0  ...   4910968.0
# 3   2893154.0   2917717.0   2924753.0   2918710.0  ...   2871734.0
# 4   5019255.0   5043207.0   5031298.0   5032007.0  ...   4927758.0
#
#          2013        2014        2015        2016        2017        2018  \
# ...

# %%
df4.head()
# Out:
#             2000  2001  2002 2003  2004  2005  2006 2007 2008  ...  2012  \
# 0  Ireland   4.3   3.7   4.2  4.5   4.5   4.3   4.4  5.0  6.8  ...  15.5
# 1  Germany   7.9   7.8   8.5  9.8  10.7  11.2  10.3  8.7  7.5  ...   5.4
# 2  Belgium   6.6   6.2   6.9  7.7   7.4   8.4   8.3  7.5  7.0  ...   7.5
# 3  Denmark   4.5   4.2   4.3  5.4   5.2   4.8   3.9  3.8  3.7  ...   7.8
# 4   Greece  11.3  10.8  10.4  9.8  10.6  10.1   8.9  8.4  7.7  ...  24.7
#
#    2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0  13.7  11.9   9.9   8.4   6.7   5.7   5.0   5.6   6.2
# 1   5.2   5.0   4.6   4.1   3.8   3.4   3.1   3.9   3.6
# 2   8.4   8.5   8.5   7.8   7.1   6.0   5.4   5.6   6.3
# 3   7.4   6.9   6.3   6.0   5.8   5.1   5.0   5.6   5.1
# 4  27.7  26.7  25.0  23.5  21.4  19.2  17.0  15.9  14.7
#
# [5 rows x 24 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0                68 non-null     object
#  1   2000         68 non-null     object
#  2   2001         68 non-null     object
#  3   2002         68 non-null     object
#  4   2003         68 non-null     object
#  5   2004         68 non-null     object
#  6   2005         68 non-null     object
#  7   2006         68 non-null     object
#  8   2007         68 non-null     object
#  9   2008         68 non-null     object
#  10  2009         68 non-null     object
#  11  Unnamed: 11  0 non-null      float64
#  12  2010         68 non-null     object
#  13  2011         68 non-null     object
#  14  2012         68 non-null     object
#  15  2013         68 non-null     object
#  16  2014         68 non-null     object
#  17  2015         68 non-null     object
# ...

# %%
#now drop unnamed: 11 column
df4 = df4.drop(columns=['Unnamed: 11'])

# %%
df1.head(2342)
# Out:
#                                2000             2001             2002  \
# 0          Ireland    31566722637.1    37268758566.1    45143959977.4
# 1          Germany   539832139038.4   526709873232.7   548277686693.3
# 2          Belgium    59065114871.1    57558079403.3    61462575829.0
# 3          Denmark    38827989880.1    37721939131.1    40471111505.2
# 4           Greece    24457701784.8    26352365530.7    30045306326.2
# ..             ...              ...              ...              ...
# 63         Tunisia     5756255927.6     5833530270.4     6150313005.6
# 64         Turkiye    73506094529.8    51453852480.4    59082397890.1
# 65         Ukraine    10246865924.0    11756668714.3    13281643074.4
# 66  United Kingdom   376258132849.1   355939254354.4   379211630695.4
# 67   United States  2301500414000.0  2271834974000.0  2257131284000.0
#
#                2003             2004             2005             2006  \
# ...

# %%
df1 = df1.transpose()
df2 = df2.transpose() 
df3 = df3.transpose()
df4 = df4.transpose()

# %%
df1.columns = [f"{col}_ValueAdded_USD" for col in df1.columns]
df2.columns = [f"{col}_Unemployment" for col in df2.columns]
df3.columns = [f"{col}_LaborForce" for col in df3.columns]
df4.columns = [f"{col}_ValueAdded_GDP" for col in df4.columns]

# %%
df_final = pd.concat([df1, df2, df3, df4], axis=1)

# %%
print(df_final.head())
# Out:
#    _ValueAdded_USD 2000_ValueAdded_USD 2001_ValueAdded_USD  \
# 0          Ireland       31566722637.1       37268758566.1
# 1          Germany      539832139038.4      526709873232.7
# 2          Belgium       59065114871.1       57558079403.3
# 3          Denmark       38827989880.1       37721939131.1
# 4           Greece       24457701784.8       26352365530.7
#
#   2002_ValueAdded_USD 2003_ValueAdded_USD 2004_ValueAdded_USD  \
# 0       45143959977.4       53121134676.0       59800704626.7
# 1      548277686693.3      655099098353.3      743125902473.0
# 2       61462575829.0       73879931157.1       84771694096.0
# 3       40471111505.2       48336610349.6       55627917744.7
# 4       30045306326.2       41521328053.9       49021674077.8
#
#   2005_ValueAdded_USD 2006_ValueAdded_USD 2007_ValueAdded_USD  \
# 0       63635542139.5       69840796138.2       77044361279.4
# 1      750242418303.5      807803314704.7      933007744317.7
# ...

# %%
# Set the first column as the index for each dataframe
df1.set_index(df1.columns[0], inplace=True)
df2.set_index(df2.columns[0], inplace=True)
df3.set_index(df3.columns[0], inplace=True)
df4.set_index(df4.columns[0], inplace=True)

# Concatenate the dataframes along the columns
df_final = pd.concat([df1, df2, df3, df4], axis=1)

# Print the first few rows to check the resulting dataframe
print(df_final.head())
# Out:
#         2000_ValueAdded_USD 2001_ValueAdded_USD 2002_ValueAdded_USD  \
# Ireland       31566722637.1       37268758566.1       45143959977.4
# Germany      539832139038.4      526709873232.7      548277686693.3
# Belgium       59065114871.1       57558079403.3       61462575829.0
# Denmark       38827989880.1       37721939131.1       40471111505.2
# Greece        24457701784.8       26352365530.7       30045306326.2
#
#         2003_ValueAdded_USD 2004_ValueAdded_USD 2005_ValueAdded_USD  \
# Ireland       53121134676.0       59800704626.7       63635542139.5
# Germany      655099098353.3      743125902473.0      750242418303.5
# Belgium       73879931157.1       84771694096.0       87070394710.7
# Denmark       48336610349.6       55627917744.7       58816297753.8
# Greece        41521328053.9       49021674077.8       44132955361.2
#
#         2006_ValueAdded_USD 2007_ValueAdded_USD 2008_ValueAdded_USD  \
# Ireland       69840796138.2       77044361279.4       71411271347.7
# ...

# %%
df_final.shape
# Out:
# (68, 92)

# %%
df_final.shape
# Out:
# (68, 92)

# %%
df_final.head(67)
# Out:
#     _ValueAdded_USD 2000_ValueAdded_USD 2001_ValueAdded_USD  \
# 0           Ireland       31566722637.1       37268758566.1
# 1           Germany      539832139038.4      526709873232.7
# 2           Belgium       59065114871.1       57558079403.3
# 3           Denmark       38827989880.1       37721939131.1
# 4            Greece       24457701784.8       26352365530.7
# ..              ...                 ...                 ...
# 62         Thailand       46347284340.3       43692887317.4
# 63          Tunisia        5756255927.6        5833530270.4
# 64          Turkiye       73506094529.8       51453852480.4
# 65          Ukraine       10246865924.0       11756668714.3
# 66   United Kingdom      376258132849.1      355939254354.4
#
#    2002_ValueAdded_USD 2003_ValueAdded_USD 2004_ValueAdded_USD  \
# 0        45143959977.4       53121134676.0       59800704626.7
# 1       548277686693.3      655099098353.3      743125902473.0
# ...

# %%
#now lets see the nan values
df_final.isnull().sum()
# Out:
#  _ValueAdded_USD       0
# 2000_ValueAdded_USD    0
# 2001_ValueAdded_USD    0
# 2002_ValueAdded_USD    0
# 2003_ValueAdded_USD    0
#                       ..
# 2017_ValueAdded_GDP    0
# 2018_ValueAdded_GDP    0
# 2019_ValueAdded_GDP    0
# 2020_ValueAdded_GDP    0
# 2021_ValueAdded_GDP    0
# Length: 92, dtype: int64

# %%
#lets drop the nan values
df_final = df_final.dropna()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 0 to 67
# Data columns (total 92 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0    _ValueAdded_USD     68 non-null     object
#  1   2000_ValueAdded_USD  68 non-null     object
#  2   2001_ValueAdded_USD  68 non-null     object
#  3   2002_ValueAdded_USD  68 non-null     object
#  4   2003_ValueAdded_USD  68 non-null     object
#  5   2004_ValueAdded_USD  68 non-null     object
#  6   2005_ValueAdded_USD  68 non-null     object
#  7   2006_ValueAdded_USD  68 non-null     object
#  8   2007_ValueAdded_USD  68 non-null     object
#  9   2008_ValueAdded_USD  68 non-null     object
#  10  2009_ValueAdded_USD  68 non-null     object
#  11  2010_ValueAdded_USD  68 non-null     object
#  12  2011_ValueAdded_USD  68 non-null     object
#  13  2012_ValueAdded_USD  68 non-null     object
#  14  2013_ValueAdded_USD  68 non-null     object
# ...

# %%
#let transpose the dataframe
df_final = df_final.transpose()

# %%
df_final.head(55)
# Out:
#                     2000_ValueAdded_USD 2001_ValueAdded_USD  \
# Ireland                   31566722637.1       37268758566.1
# Germany                  539832139038.4      526709873232.7
# Belgium                   59065114871.1       57558079403.3
# Denmark                   38827989880.1       37721939131.1
# Greece                    24457701784.8       26352365530.7
# Spain                    167357670269.8      175512040368.1
# Italy                    278749222854.3      281736657914.1
# Netherlands               90761557967.1       94488915157.5
# Norway                    62496307573.5       61247928645.3
# Austria                   55802980000.8       55714748447.5
# Hungary                   12771894597.5       14586580566.3
# Slovak Republic            8602240961.7        9186375336.2
# Slovenia                   6181817692.6        6377836130.3
# Poland                    49587446216.1       52282664452.0
# Sweden                    69317740280.7       63057865641.7
# ...
